# %% [markdown]
# ### Opening Image with OpenCV

# %%
import cv2

img = cv2.imread('C:\\Users\\Sorcim\\Computer Vision with OpenCV and Deep Learning\\DATA\\lion.jpg')

cv2.imshow('image',img)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# ### Drawing on Images
# #### Part One

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
blank_img = np.zeros(shape=(512,512,3), dtype=np.int16)

# %%
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img);

# %% [markdown]
# ### Draw a Rectangle

# %%
cv2.rectangle(blank_img, pt1=(185,100), pt2=(485, 285), color=(0,255,0), thickness=10)
plt.imshow(blank_img);

# %%
cv2.rectangle(blank_img, pt1=(200, 200), pt2=(300, 300), color=(0,0,255), thickness=5)
plt.imshow(blank_img)

# %% [markdown]
# ### Draw a Circles

# %%
cv2.circle(img=blank_img, center=(100,100), radius=60, color=(233, 0,0), thickness=4)
plt.imshow(blank_img);

# %%
cv2.circle(img=blank_img, center=(400,420), radius=60, color=(255, 0,0), thickness=-1)
plt.imshow(blank_img);

# %%
cv2.line(blank_img, pt1=(12, 12), pt2=(500, 500), color=(123, 233, 233), thickness=5)
plt.imshow(blank_img);

# %% [markdown]
# ### Writing Text on Images

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img, text='Hello', org=(10, 500), fontFace = font, fontScale=5, color=(255,255,255),
           thickness=3, lineType=cv2.LINE_AA)
## Ord is the bottom left corner
plt.imshow(blank_img);

# %% [markdown]
# ### Draw a ploygon

# %%
blank_img = np.zeros(shape=(512, 512, 3), dtype=np.int32)
plt.imshow(blank_img);

# %%
vertices = np.array([[100, 300], [200, 200], [400, 300], [200, 400]], dtype= np.int32 )

# %%
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]])

# %%
vertices.shape
# Out:
# (4, 2)

# %%
vertices.reshape(-1,1,2)
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]])

# %%
vertices.shape
# Out:
# (4, 2)

# %%
cv2.polylines(blank_img, [vertices], isClosed=True, color=(255,0, 0), thickness=3)
plt.imshow(blank_img);
